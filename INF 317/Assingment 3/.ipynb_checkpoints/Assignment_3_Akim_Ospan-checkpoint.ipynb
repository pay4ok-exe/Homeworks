# %% [markdown]
# ##Assignment 3: <font color='3C6E71'></font>
#
#
# ####Total Points: 5 points)
# \
#
# ----
# **Objective:**
#
# In this assignment, you will work with time series data, applying data wrangling techniques including merging and concatenation, and performing time-based analysis using Python libraries: Pandas, NumPy, and Matplotlib/Seaborn.
#
# ----
#
# ## **Instructions:**
#
# ### **1. Data Collection:**
# - Find or download a time series dataset from a public source. Examples could include stock prices, weather data, COVID-19 cases, or energy consumption over time.
# - Make sure the dataset includes a time or date column to analyze time-based trends.
#
# ### **2. Data Wrangling (Merging and Concatenation):**
# - Split your dataset into two or more parts (e.g., by year, location, or category).
# - Concatenation: Concatenate the parts back together and verify that the data structure remains consistent.
# - Merging: Locate an additional dataset related to your main dataset and merge it to enrich the original data. For example, if analyzing stock prices, you might merge in economic indicators.
#
# ### **3. Data Cleaning and Preparation:**
#
# - Clean the dataset by handling missing values, removing duplicates, and converting data types where necessary.
# - Standardize the time format (if required) and set it as the index of your DataFrame.
#
# ### **4. Time Series Analysis:**
# - Perform time-based resampling (e.g., monthly or quarterly aggregation) and calculate summary statistics for each period.
# - Identify trends, seasonal patterns, or cycles within the time series data.
# - Calculate rolling statistics (e.g., moving average) to smooth out noise and highlight trends.
#
# ### **5. Data Visualization:**
# - Create at least five visualizations that showcase trends, patterns, or relationships in the time series data.
# - Examples include line plots, seasonal decomposition plots, rolling statistics visualizations, and heatmaps.
# - Label the visualizations clearly and provide meaningful insights.
#
# ### **6. Comment Your Code:**
#
# - Comment on each section of your code, explaining each step and the rationale behind your approach.
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('anime.csv')
df.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes  start_date    end_date        source  ...  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' vi...
# 4  Koe no Katachi won the following awards: Japan...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/1935/...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24985 entries, 0 to 24984
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24985 non-null  int64
#  1   title             24985 non-null  object
#  2   type              24927 non-null  object
#  3   score             16050 non-null  float64
#  4   scored_by         24985 non-null  int64
#  5   status            24985 non-null  object
#  6   episodes          24438 non-null  float64
#  7   start_date        24110 non-null  object
#  8   end_date          22215 non-null  object
#  9   source            21424 non-null  object
#  10  members           24985 non-null  int64
#  11  favorites         24985 non-null  int64
#  12  episode_duration  24387 non-null  object
#  13  total_duration    24162 non-null  object
#  14  rating            24405 non-null  object
#  15  sfw               24985 non-null  bool
#  16  approved          24985 non-null  bool
#  17  created_at        24985 non-null  object
#  18  updated_at        24985 non-null  object
#  19  start_year        20301 non-null  float64
#  20  start_season      20301 non-null  object
#  21  real_start_date   24110 non-null  object
#  22  real_end_date     22215 non-null  object
#  23  broadcast_day     3450 non-null   object
#  24  broadcast_time    3313 non-null   object
#  25  genres            24985 non-null  object
#  26  themes            24985 non-null  object
#  27  demographics      24985 non-null  object
#  28  studios           24985 non-null  object
#  29  producers         24985 non-null  object
#  30  licensors         24985 non-null  object
#  31  synopsis          20492 non-null  object
#  32  background        2450 non-null   object
#  33  main_picture      24831 non-null  object
#  34  url               24985 non-null  object
#  35  trailer_url       4724 non-null   object
#  36  title_english     10402 non-null  object
#  37  title_japanese    24895 non-null  object
#  38  title_synonyms    24985 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(30)
# memory usage: 7.1+ MB

# %%
# Check for missing values and handle them (fill or drop)
df.isnull().sum()
# Out:
# anime_id                0
# title                   0
# type                   58
# score                8935
# scored_by               0
# status                  0
# episodes              547
# start_date            875
# end_date             2770
# source               3561
# members                 0
# favorites               0
# episode_duration      598
# total_duration        823
# rating                580
# sfw                     0
# approved                0
# created_at              0
# updated_at              0
# start_year           4684
# start_season         4684
# real_start_date       875
# real_end_date        2770
# broadcast_day       21535
# broadcast_time      21672
# genres                  0
# themes                  0
# demographics            0
# studios                 0
# producers               0
# licensors               0
# synopsis             4493
# background          22535
# main_picture          154
# url                     0
# trailer_url         20261
# title_english       14583
# title_japanese         90
# title_synonyms          0
# dtype: int64

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')

# Drop rows with missing 'start_date' values
df = df.dropna(subset=['start_date'])

# Split dataset into two groups: before 2000 and from 2000 onwards
df_before_2000 = df[df['start_date'].dt.year < 2000]
df_2000_and_later = df[df['start_date'].dt.year >= 2000]

# %%
df_before_2000.head()
# Out:
#     anime_id                                           title   type  score  \
# 11        21                                       One Piece     tv   8.70
# 17         1                                    Cowboy Bebop     tv   8.75
# 30       164                                   Mononoke Hime  movie   8.67
# 46        32  Neon Genesis Evangelion: The End of Evangelion  movie   8.55
# 49        30                         Neon Genesis Evangelion     tv   8.35
#
#     scored_by            status  episodes start_date    end_date    source  \
# 11    1248354  currently_airing       NaN 1999-10-20         NaN     manga
# 17     923377   finished_airing      26.0 1998-04-03  1999-04-24  original
# 30     776491   finished_airing       1.0 1997-07-12  1997-07-12  original
# 46     593685   finished_airing       1.0 1997-07-19  1997-07-19  original
# 49    1036816   finished_airing      26.0 1995-10-04  1996-03-27  original
#
#     ...                                          producers  \
# 11  ...                     ['Fuji TV', 'TAP', 'Shueisha']
# 17  ...                                  ['Bandai Visual']
# 30  ...     ['Tokuma Shoten', 'Nippon Television Network']
# 46  ...  ['TV Tokyo', 'Toei Animation', 'Kadokawa Shote...
# 49  ...  ['TV Tokyo', 'Kadokawa Shoten', 'Nihon Ad Syst...
#
#                                  licensors  \
# 11   ['Funimation', '4Kids Entertainment']
# 17  ['Funimation', 'Bandai Entertainment']
# 30                               ['GKIDS']
# 46        ['GKIDS', 'Manga Entertainment']
# 49                  ['ADV Films', 'GKIDS']
#
#                                              synopsis  \
# 11  Barely surviving in a barrel after passing thr...
# 17  Crime is timeless. By the year 2071, humanity ...
# 30  When an Emishi village is attacked by a fierce...
# 46  Shinji Ikari is left emotionally comatose afte...
# 49  Fifteen years after a cataclysmic event known ...
#
#                                            background  \
# 11  Several anime-original arcs have been adapted ...
# 17  When Cowboy Bebop first aired in spring of 199...
# 30  In 1997 the film won Best Japanese Movie, Best...
# 46  Shinseiki Evangelion Gekijouban: The End of Ev...
# 49  Director Hideaki Anno's depression is what led...
#
#                                          main_picture  \
# 11  https://cdn.myanimelist.net/images/anime/6/732...
# 17  https://cdn.myanimelist.net/images/anime/4/196...
# 30  https://cdn.myanimelist.net/images/anime/7/759...
# 46  https://cdn.myanimelist.net/images/anime/1404/...
# 49  https://cdn.myanimelist.net/images/anime/1314/...
#
#                                                   url  \
# 11         https://myanimelist.net/anime/21/One_Piece
# 17       https://myanimelist.net/anime/1/Cowboy_Bebop
# 30    https://myanimelist.net/anime/164/Mononoke_Hime
# 46  https://myanimelist.net/anime/32/Neon_Genesis_...
# 49  https://myanimelist.net/anime/30/Neon_Genesis_...
#
#                                     trailer_url  \
# 11  https://www.youtube.com/watch?v=l_98K4_6UQ0
# 17  https://www.youtube.com/watch?v=qig4KOK2R2g
# 30  https://www.youtube.com/watch?v=4OiMOHRDs14
# 46  https://www.youtube.com/watch?v=Gk72E4qgEng
# 49                                          NaN
#
#                                      title_english  \
# 11                                       One Piece
# 17                                    Cowboy Bebop
# 30                               Princess Mononoke
# 46  Neon Genesis Evangelion: The End of Evangelion
# 49                         Neon Genesis Evangelion
#
#                           title_japanese  \
# 11                             ONE PIECE
# 17                             カウボーイビバップ
# 30                                 もののけ姫
# 46  新世紀エヴァンゲリオン劇場版 THE END OF EVANGELION
# 49                           新世紀エヴァンゲリオン
#
#                                        title_synonyms
# 11                                             ['OP']
# 17                                                 []
# 30                                  ['Mononoke Hime']
# 46  ['Shinseiki Evangelion Gekijouban: The End of ...
# 49                           ['Shinseiki Evangelion']
#
# [5 rows x 39 columns]

# %%
df_2000_and_later.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes start_date    end_date        source  ...  \
# 0  finished_airing      64.0 2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0 2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0 2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0 2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0 2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' vi...
# 4  Koe no Katachi won the following awards: Japan...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/1935/...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']
#
# [5 rows x 39 columns]

# %%
df_concat = pd.concat([df_before_2000, df_2000_and_later])
df_concat
# Out:
#        anime_id                                             title   type  \
# 11           21                                         One Piece     tv
# 17            1                                      Cowboy Bebop     tv
# 30          164                                     Mononoke Hime  movie
# 46           32    Neon Genesis Evangelion: The End of Evangelion  movie
# 49           30                           Neon Genesis Evangelion     tv
# ...         ...                                               ...    ...
# 24977     56144  Jijia Yingxiong Movie: Wo Yu Wo Dengyu Wuxian Da  movie
# 24979     56169                                            Tettou  music
# 24982     56107                              Kaijuu Sekai Seifuku    ona
# 24983     56168                               Yotsukado no Melody  music
# 24984     56202                                     Ame to Kusari  music
#
#        score  scored_by            status  episodes start_date    end_date  \
# 11      8.70    1248354  currently_airing       NaN 1999-10-20         NaN
# 17      8.75     923377   finished_airing      26.0 1998-04-03  1999-04-24
# 30      8.67     776491   finished_airing       1.0 1997-07-12  1997-07-12
# 46      8.55     593685   finished_airing       1.0 1997-07-19  1997-07-19
# 49      8.35    1036816   finished_airing      26.0 1995-10-04  1996-03-27
# ...      ...        ...               ...       ...        ...         ...
# 24977    NaN          1   finished_airing       1.0 2023-08-04  2023-08-04
# 24979    NaN          6   finished_airing       1.0 2019-10-01  2019-10-01
# 24982    NaN          2  currently_airing       NaN 2020-04-02         NaN
# 24983    NaN          1   finished_airing       1.0 2014-12-01  2014-12-01
# 24984    NaN          0   finished_airing       1.0 2015-08-05  2015-08-05
#
#           source  ...                                          producers  \
# 11         manga  ...                     ['Fuji TV', 'TAP', 'Shueisha']
# 17      original  ...                                  ['Bandai Visual']
# 30      original  ...     ['Tokuma Shoten', 'Nippon Television Network']
# 46      original  ...  ['TV Tokyo', 'Toei Animation', 'Kadokawa Shote...
# 49      original  ...  ['TV Tokyo', 'Kadokawa Shoten', 'Nihon Ad Syst...
# ...          ...  ...                                                ...
# 24977       game  ...                                      ['Stay Luck']
# 24979   original  ...                                            ['NHK']
# 24982  web_manga  ...                                                 []
# 24983   original  ...                                            ['NHK']
# 24984   original  ...                                                 []
#
#                                     licensors  \
# 11      ['Funimation', '4Kids Entertainment']
# 17     ['Funimation', 'Bandai Entertainment']
# 30                                  ['GKIDS']
# 46           ['GKIDS', 'Manga Entertainment']
# 49                     ['ADV Films', 'GKIDS']
# ...                                       ...
# 24977                                      []
# 24979                                      []
# 24982                                      []
# 24983                                      []
# 24984                                      []
#
#                                                 synopsis  \
# 11     Barely surviving in a barrel after passing thr...
# 17     Crime is timeless. By the year 2071, humanity ...
# 30     When an Emishi village is attacked by a fierce...
# 46     Shinji Ikari is left emotionally comatose afte...
# 49     Fifteen years after a cataclysmic event known ...
# ...                                                  ...
# 24977                                                NaN
# 24979  Music video for the song Tettou by Asaco Nasu ...
# 24982  Follows four dragon-like monsters who came to ...
# 24983  Music video for the song Yotsukado no Melody b...
# 24984  Music video for the song Ame to Kusari by otetsu.
#
#                                               background  \
# 11     Several anime-original arcs have been adapted ...
# 17     When Cowboy Bebop first aired in spring of 199...
# 30     In 1997 the film won Best Japanese Movie, Best...
# 46     Shinseiki Evangelion Gekijouban: The End of Ev...
# 49     Director Hideaki Anno's depression is what led...
# ...                                                  ...
# 24977                                                NaN
# 24979                                                NaN
# 24982                                                NaN
# 24983                                                NaN
# 24984                                                NaN
#
#                                             main_picture  \
# 11     https://cdn.myanimelist.net/images/anime/6/732...
# 17     https://cdn.myanimelist.net/images/anime/4/196...
# 30     https://cdn.myanimelist.net/images/anime/7/759...
# 46     https://cdn.myanimelist.net/images/anime/1404/...
# 49     https://cdn.myanimelist.net/images/anime/1314/...
# ...                                                  ...
# 24977  https://cdn.myanimelist.net/images/anime/1419/...
# 24979  https://cdn.myanimelist.net/images/anime/1918/...
# 24982  https://cdn.myanimelist.net/images/anime/1859/...
# 24983  https://cdn.myanimelist.net/images/anime/1559/...
# 24984  https://cdn.myanimelist.net/images/anime/1518/...
#
#                                                      url  \
# 11            https://myanimelist.net/anime/21/One_Piece
# 17          https://myanimelist.net/anime/1/Cowboy_Bebop
# 30       https://myanimelist.net/anime/164/Mononoke_Hime
# 46     https://myanimelist.net/anime/32/Neon_Genesis_...
# 49     https://myanimelist.net/anime/30/Neon_Genesis_...
# ...                                                  ...
# 24977  https://myanimelist.net/anime/56144/Jijia_Ying...
# 24979         https://myanimelist.net/anime/56169/Tettou
# 24982  https://myanimelist.net/anime/56107/Kaijuu_Sek...
# 24983  https://myanimelist.net/anime/56168/Yotsukado_...
# 24984  https://myanimelist.net/anime/56202/Ame_to_Kusari
#
#                                        trailer_url  \
# 11     https://www.youtube.com/watch?v=l_98K4_6UQ0
# 17     https://www.youtube.com/watch?v=qig4KOK2R2g
# 30     https://www.youtube.com/watch?v=4OiMOHRDs14
# 46     https://www.youtube.com/watch?v=Gk72E4qgEng
# 49                                             NaN
# ...                                            ...
# 24977  https://www.youtube.com/watch?v=t3pQv7qMgug
# 24979                                          NaN
# 24982                                          NaN
# 24983                                          NaN
# 24984                                          NaN
#
#                                         title_english  \
# 11                                          One Piece
# 17                                       Cowboy Bebop
# 30                                  Princess Mononoke
# 46     Neon Genesis Evangelion: The End of Evangelion
# 49                            Neon Genesis Evangelion
# ...                                               ...
# 24977                                             NaN
# 24979                                             NaN
# 24982                                             NaN
# 24983                                             NaN
# 24984                                             NaN
#
#                              title_japanese  \
# 11                                ONE PIECE
# 17                                カウボーイビバップ
# 30                                    もののけ姫
# 46     新世紀エヴァンゲリオン劇場版 THE END OF EVANGELION
# 49                              新世紀エヴァンゲリオン
# ...                                     ...
# 24977                      機甲英雄劇場版 我與我等於無限大
# 24979                                    鉄塔
# 24982                          かいじゅうせかいせいふく
# 24983                             四つ角のメロディー
# 24984                                   飴と鎖
#
#                                           title_synonyms
# 11                                                ['OP']
# 17                                                    []
# 30                                     ['Mononoke Hime']
# 46     ['Shinseiki Evangelion Gekijouban: The End of ...
# 49                              ['Shinseiki Evangelion']
# ...                                                  ...
# 24977                           ['Hero of Robots Movie']
# 24979                                   ['Minna no Uta']
# 24982                                                 []
# 24983                                   ['Minna no Uta']
# 24984                               ['Candy and Chains']
#
# [24110 rows x 39 columns]

# %%
df2 = pd.read_csv('AnimeList.csv')
df2[df2['title'] == 'One Piece']
# Out:
#     anime_id      title title_english title_japanese title_synonyms  \
# 34        21  One Piece     One Piece      ONE PIECE             OP
#
#                                             image_url type source  episodes  \
# 34  https://myanimelist.cdn-dena.com/images/anime/...   TV  Manga         0
#
#               status  ...                                         background  \
# 34  Currently Airing  ...  Several anime-original arcs have been adapted ...
#
#     premiered               broadcast  \
# 34  Fall 1999  Sundays at 09:30 (JST)
#
#                                               related                producer  \
# 34  {'Adaptation': [{'mal_id': 13, 'type': 'manga'...  Fuji TV, TAP, Shueisha
#
#                            licensor          studio  \
# 34  Funimation, 4Kids Entertainment  Toei Animation
#
#                                                 genre  \
# 34  Action, Adventure, Comedy, Super Power, Drama,...
#
#                                         opening_theme  \
# 34  ['#01: "We Are! (ウィーアー!)" by Hiroshi Kitadani ...
#
#                                          ending_theme
# 34  ['#01: "memories" by Maki Otsuki (eps 1-30)', ...
#
# [1 rows x 31 columns]

# %%
print(len(df2))
df2[df2['anime_id'] == 11013]
# Out:
# 14478
#    anime_id          title              title_english title_japanese  \
# 0     11013  Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
#
#     title_synonyms                                          image_url type  \
# 0  Youko x Boku SS  https://myanimelist.cdn-dena.com/images/anime/...   TV
#
#   source  episodes           status  ...  \
# 0  Manga        12  Finished Airing  ...
#
#                                           background    premiered  \
# 0  Inu x Boku SS was licensed by Sentai Filmworks...  Winter 2012
#
#             broadcast                                            related  \
# 0  Fridays at Unknown  {'Adaptation': [{'mal_id': 17207, 'type': 'man...
#
#                                             producer          licensor  \
# 0  Aniplex, Square Enix, Mainichi Broadcasting Sy...  Sentai Filmworks
#
#              studio                                   genre  \
# 0  David Production  Comedy, Supernatural, Romance, Shounen
#
#            opening_theme                                       ending_theme
# 0  ['"Nirvana" by MUCC']  ['#1: "Nirvana" by MUCC (eps 1, 11-12)', '#2: ...
#
# [1 rows x 31 columns]

# %%
print(len(df))
df[df['anime_id'] == 11013]
# Out:
# 24110
#      anime_id          title type  score  scored_by           status  \
# 976     11013  Inu x Boku SS   tv   7.38     231579  finished_airing
#
#      episodes start_date    end_date source  ...  \
# 976      12.0 2012-01-13  2012-03-30  manga  ...
#
#                                              producers             licensors  \
# 976  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...  ['Sentai Filmworks']
#
#                                               synopsis  \
# 976  Ririchiyo Shirakiin is the sheltered daughter ...
#
#                                             background  \
# 976  Inu x Boku SS was licensed by Sentai Filmworks...
#
#                                           main_picture  \
# 976  https://cdn.myanimelist.net/images/anime/1760/...
#
#                                                    url  trailer_url  \
# 976  https://myanimelist.net/anime/11013/Inu_x_Boku_SS          NaN
#
#                  title_english title_japanese       title_synonyms
# 976  Inu X Boku Secret Service         妖狐×僕SS  ['Youko x Boku SS']
#
# [1 rows x 39 columns]

# %%
df_merged = pd.merge(df, df2, on='anime_id', how='outer')
df_merged.head()
# Out:
#    anime_id                          title_x type_x  score_x  scored_by_x  \
# 0         1                     Cowboy Bebop     tv     8.75     923377.0
# 1         5  Cowboy Bebop: Tengoku no Tobira  movie     8.38     207777.0
# 2         6                           Trigun     tv     8.22     359862.0
# 3         7               Witch Hunter Robin     tv     7.25      43038.0
# 4         8                   Bouken Ou Beet     tv     6.94       6445.0
#
#           status_x  episodes_x start_date    end_date  source_x  ...  \
# 0  finished_airing        26.0 1998-04-03  1999-04-24  original  ...
# 1  finished_airing         1.0 2001-09-01  2001-09-01  original  ...
# 2  finished_airing        26.0 1998-04-01  1998-09-30     manga  ...
# 3  finished_airing        26.0 2002-07-03  2002-12-25  original  ...
# 4  finished_airing        52.0 2004-09-30  2005-09-29     manga  ...
#
#                                         background_y    premiered  \
# 0  When Cowboy Bebop first aired in spring of 199...  Spring 1998
# 1                                                NaN          NaN
# 2  The Japanese release by Victor Entertainment h...  Spring 1998
# 3                                                NaN  Summer 2002
# 4                                                NaN    Fall 2004
#
#                   broadcast  \
# 0  Saturdays at 01:00 (JST)
# 1                       NaN
# 2  Thursdays at 01:15 (JST)
# 3       Tuesdays at Unknown
# 4                   Unknown
#
#                                              related                producer  \
# 0  {'Adaptation': [{'mal_id': 173, 'type': 'manga...           Bandai Visual
# 1  {'Parent story': [{'mal_id': 1, 'type': 'anime...  Sunrise, Bandai Visual
# 2  {'Adaptation': [{'mal_id': 703, 'type': 'manga...    Victor Entertainment
# 3                                                 []           Bandai Visual
# 4  {'Adaptation': [{'mal_id': 1348, 'type': 'mang...                     NaN
#
#                                licensor          studio  \
# 0      Funimation, Bandai Entertainment         Sunrise
# 1           Sony Pictures Entertainment           Bones
# 2  Funimation, Geneon Entertainment USA        Madhouse
# 3      Funimation, Bandai Entertainment         Sunrise
# 4                                   NaN  Toei Animation
#
#                                                genre  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1              Action, Space, Drama, Mystery, Sci-Fi
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3  Action, Magic, Police, Supernatural, Drama, My...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                        opening_theme  \
# 0            ['"Tank!" by The Seatbelts (eps 1-25)']
# 1  ['"Ask DNA" by The Seatbelts featuring Raju Ra...
# 2                       ['"H.T." by Tsuneo Imahori']
# 3                                ['"Shell" by Bana']
# 4  ['#1: "Emotion" by Sunbrain', '#2: "Wish Men" ...
#
#                                         ending_theme
# 0  ['#1: "The Real Folk Blues" by The Seatbelts f...
# 1  ['"Gotta Knock a Little Harder" by The Seatbel...
# 2  ['"Kaze wa Mirai ni Fuku (The Wind Blows to th...
# 3  ['#1: "Half Pain" by Bana (eps 01-14,16-25)', ...
# 4  ['#1: "pureness" by Nana Kitade (eps 1-13)', '...
#
# [5 rows x 69 columns]

# %%
len(df['anime_id'].unique())
# Out:
# 24110

# %%
len(df2['anime_id'].unique())
# Out:
# 14478

# %%
len(df_merged['anime_id'].unique())
# Out:
# 24324

# %%
# Step 3: 
df_cleaned = df.copy()
df_cleaned.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes start_date    end_date        source  ...  \
# 0  finished_airing      64.0 2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0 2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0 2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0 2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0 2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' vi...
# 4  Koe no Katachi won the following awards: Japan...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/1935/...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']
#
# [5 rows x 39 columns]

# %%
df_cleaned.isnull().sum()
# Out:
# anime_id                0
# title                   0
# type                    5
# score                8072
# scored_by               0
# status                  0
# episodes              372
# start_date              0
# end_date             1897
# source               3484
# members                 0
# favorites               0
# episode_duration      375
# total_duration        595
# rating                455
# sfw                     0
# approved                0
# created_at              0
# updated_at              0
# start_year           3809
# start_season         3809
# real_start_date         0
# real_end_date        1897
# broadcast_day       20661
# broadcast_time      20798
# genres                  0
# themes                  0
# demographics            0
# studios                 0
# producers               0
# licensors               0
# synopsis             3884
# background          21681
# main_picture          137
# url                     0
# trailer_url         19477
# title_english       13829
# title_japanese         84
# title_synonyms          0
# dtype: int64

# %%
df_cleaned['score']
# Out:
# 0        9.10
# 1        9.04
# 2        9.05
# 3        9.07
# 4        8.94
#          ...
# 24980     NaN
# 24981     NaN
# 24982     NaN
# 24983     NaN
# 24984     NaN
# Name: score, Length: 24110, dtype: float64

# %%
df_cleaned.columns
# Out:
# Index(['anime_id', 'title', 'type', 'score', 'scored_by', 'status', 'episodes',
#        'start_date', 'end_date', 'source', 'members', 'favorites',
#        'episode_duration', 'total_duration', 'rating', 'sfw', 'approved',
#        'created_at', 'updated_at', 'start_year', 'start_season',
#        'real_start_date', 'real_end_date', 'broadcast_day', 'broadcast_time',
#        'genres', 'themes', 'demographics', 'studios', 'producers', 'licensors',
#        'synopsis', 'background', 'main_picture', 'url', 'trailer_url',
#        'title_english', 'title_japanese', 'title_synonyms'],
#       dtype='object')

# %%
# Fill missing values for numerical columns with 0
numeric_columns = df_cleaned.select_dtypes(include=['float64', 'int64']).columns
df_cleaned[numeric_columns] = df_cleaned[numeric_columns].fillna(0)
df_cleaned.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes start_date    end_date        source  ...  \
# 0  finished_airing      64.0 2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0 2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0 2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0 2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0 2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' vi...
# 4  Koe no Katachi won the following awards: Japan...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/1935/...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']
#
# [5 rows x 39 columns]

# %%
# Fill missing values for categorical/text columns with an empty string or "Unknown"
text_columns = df_cleaned.select_dtypes(include=['object']).columns
df_cleaned[text_columns] = df_cleaned[text_columns].fillna("Unknown")
df_cleaned.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes start_date    end_date        source  ...  \
# 0  finished_airing      64.0 2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0 2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0 2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0 2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0 2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                            Unknown
# 1                                            Unknown
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' vi...
# 4  Koe no Katachi won the following awards: Japan...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/1935/...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']
#
# [5 rows x 39 columns]

# %%
# Step 2: Convert Data Types
df_cleaned['year_category'] = ['Before 2000' if year < 2000 else '2000 and Later' for year in df_cleaned['start_year']]
df_cleaned = df_cleaned[df_cleaned['genres'] != '[]']

df_cleaned['start_date'] = pd.to_datetime(df_cleaned['start_date'], errors='coerce')
df_cleaned['end_date'] = pd.to_datetime(df_cleaned['end_date'], errors='coerce')
df_cleaned['end_date'] = df_cleaned['end_date'].fillna(datetime.today())
df_cleaned.isnull().sum()
# Out:
# anime_id            0
# title               0
# type                0
# score               0
# scored_by           0
# status              0
# episodes            0
# start_date          0
# end_date            0
# source              0
# members             0
# favorites           0
# episode_duration    0
# total_duration      0
# rating              0
# sfw                 0
# approved            0
# created_at          0
# updated_at          0
# start_year          0
# start_season        0
# real_start_date     0
# real_end_date       0
# broadcast_day       0
# broadcast_time      0
# genres              0
# themes              0
# demographics        0
# studios             0
# producers           0
# licensors           0
# synopsis            0
# background          0
# main_picture        0
# url                 0
# trailer_url         0
# title_english       0
# title_japanese      0
# title_synonyms      0
# year_category       0
# dtype: int64

# %%
df_cleaned['start_year'] = df_cleaned['start_date'].dt.year
anime_per_year = df_cleaned[df_cleaned['start_year'] != 0.0].groupby('start_year').size()
# Display the count of anime created each year
print("Anime Created per Year:")
anime_per_year
# Out:
# Anime Created per Year:
# start_year
# 1917      17
# 1918       9
# 1924       5
# 1925       9
# 1926       6
#         ...
# 2021    1102
# 2022    1038
# 2023     649
# 2024      83
# 2025       5
# Length: 104, dtype: int64

# %%
# Visualization 1: Top 10 Most Popular Anime Titles by Members
plt.figure(figsize=(10, 6))
anime_per_year.nlargest(10).plot(kind='bar', color='skyblue')
plt.show()

# %%
# Visualization 2: Top 10 Most Popular Anime Titles by Members
top_anime_by_members = df_cleaned.nlargest(10, 'members')[['title', 'members']].set_index('title')
plt.figure(figsize=(10, 6))
top_anime_by_members.plot(kind='bar')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Visualization 3: Average Anime Score by Year
anime_score_year = df_cleaned.groupby('start_year')['score'].mean().dropna()
plt.figure(figsize=(12, 6))
anime_score_year.plot(kind='line', marker='o')
plt.show()

# %%
# Visualization 4: Top 10 Most Common Genres
genre_counts = df_cleaned[df_cleaned['genres'] != '[]']['genres'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_counts.values, y=genre_counts.index)
plt.show()

# %%
# Visualization 5: Top Plot using the dynamically selected genres
anime_genre_counts = anime_df_filtered.explode('genres').groupby(['year_category', 'genres']).size().unstack().fillna(0)
top_genres = anime_genre_counts.sum().nlargest(4).index
anime_genre_counts[top_genres].plot(kind='bar', stacked=True, figsize=(14, 7), legend=True)
plt.show()
